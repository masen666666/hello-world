# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def func(m,k): 
    return np.arccos(m/(m+k))/np.pi*180

# %%
# make these smaller to increase the resolution
# dx, dy = 0.15, 0.05
# generate 2 2d grids for the x & y bounds
# y, x = np.mgrid[slice(-3, 3 + dy, dy),
#                 slice(-3, 3 + dx, dx)]
# x and y are bounds, so z should be the value *inside* those bounds.
# Therefore, remove the last value from the z array.
m_min,k_min=1,1
m_max,k_max=100,100
m=np.arange(1,100)
k=np.arange(1,100)
X,Y = np.meshgrid(m, k)

z=func(X,Y)
z_min, z_max = z.min(), np.abs(z).max()

# fig, axs = plt.subplots(2, 2)
fig, axs = plt.subplots()
ax = axs
c = ax.pcolor(X, Y, z, cmap='RdBu', vmin=z_min, vmax=z_max)
ax.set_title('degree_thita')
plt.xlabel('m')
plt.ylabel('k')
fig.colorbar(c, ax=ax)
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, z)
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('Simplest default with labels')
# Out:
# Text(0.5, 1.0, 'Simplest default with labels')

# %%
# w=2
# func = lambda r:np.exp(-r**2/(2*w**2))/(w*np.sqrt(np.pi))
# r = np.linspace(-10,10,100)
k=np.arange(1,40+1)
m=1
thita=np.arccos(m/(m+k))/np.pi*180

plt.plot(k, thita)
# plt.axhline(0,color='Red')
plt.grid()
plt.xlabel('k')
plt.ylabel('thita(degree)')
plt.show()

# %%
m=np.arange(1,40+1)
k=2
thita=np.arccos(m/(m+k))/np.pi*180

plt.plot(m, thita)
# plt.axhline(0,color='Red')
plt.grid()
plt.xlabel('m')
plt.ylabel('thita(degree)')
plt.show()

# %%
m=np.arange(1,4)
k=np.arange(2,5)
m*k
# Out:
# array([ 2,  6, 12])

# %%
import numpy as np
import matplotlib.pyplot as plt


def z_func(x, y):
    return np.arccos(m/(m+k))/np.pi*180
m=np.arange(1,100+1)
k=np.arange(1,100+1)
M, K = np.meshgrid(m, k)

Z = z_func(M,K) 


# im = plt.imshow(Z, cmap=plt.cm.RdBu, extent=(1, 100, 1, 100))  
# # cset = plt.contour(Z, np.arange(-1, 1.5, 0.2), linewidths=2,
# #                    cmap=plt.cm.Set2,
# #                    extent=(-3, 3, -3, 3))
# # plt.clabel(cset, inline=True, fmt='%1.1f', fontsize=10)
# plt.colorbar(im)  

# plt.title('$z=(1-x^2+y^3) e^{-(x^2+y^2)/2}$')

# plt.show()
x-m
y-k

# %%
# the function to be plotted
def func(x,y):    
    # gives vertical color bars if x is horizontal axis
    return np.arccos(x/(x+y))/np.pi*180

import pylab

# define the grid over which the function should be plotted (xx and yy are matrices)
xx, yy = pylab.meshgrid(
    pylab.linspace(0,40, 101),
    pylab.linspace(0,100, 111))

# indexing of xx and yy (with the default value for the
# 'indexing' parameter of meshgrid(..) ) is as follows:
#
#   first index  (row index)    is y coordinate index
#   second index (column index) is x coordinate index
#
# as required by pcolor(..)

# fill a matrix with the function values
zz = pylab.zeros(xx.shape)
for i in range(xx.shape[0]):
    for j in range(xx.shape[1]):
        zz[i,j] = func(xx[i,j], yy[i,j])

# plot the calculated function values
pylab.pcolor(xx,yy,zz)

# and a color bar to show the correspondence between function value and color
pylab.colorbar()

pylab.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
